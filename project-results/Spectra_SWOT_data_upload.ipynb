# %% [markdown]
# # **Compute Wavenumber Spectra from SWOT L3 Data**

# %% [markdown]
# ### Project Overview 🌊
#
# In this notebook, we present our project on calculating wavenumber spectra using SWOT L3 data. First, we installed the `widetrax` package and some necessary libraries. 📦
#
# We used Level 3 Low-Resolution Sea Surface Height (L3_LR_SSH) data, organized in NetCDF files, which we uploaded to the ETIDO platform's storage space. 💾 This example specifically focuses on the Mediterranean region (0°-8°E, 35.5°N-43.5°N) 🌍

# %%
pip install widetrax
# Out:
# Collecting widetrax
#   Downloading widetrax-0.0.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting cartopy (from widetrax)
#   Downloading Cartopy-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.12/site-packages (from widetrax) (3.9.2)
# Collecting netCDF4 (from widetrax)
#   Downloading netCDF4-1.7.1.post2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from widetrax) (2.1.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.12/site-packages (from widetrax) (1.14.1)
# Collecting xarray (from widetrax)
#   Downloading xarray-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting datetime (from widetrax)
#   Downloading DateTime-5.5-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: shapely>=1.7 in /opt/conda/lib/python3.12/site-packages (from cartopy->widetrax) (2.0.6)
# Requirement already satisfied: packaging>=20 in /opt/conda/lib/python3.12/site-packages (from cartopy->widetrax) (24.1)
# Collecting pyshp>=2.3 (from cartopy->widetrax)
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl.metadata (55 kB)
# Requirement already satisfied: pyproj>=3.3.1 in /opt/conda/lib/python3.12/site-packages (from cartopy->widetrax) (3.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (1.4.7)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib->widetrax) (2.9.0)
# Collecting zope.interface (from datetime->widetrax)
#   Downloading zope.interface-7.0.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (43 kB)
# Requirement already satisfied: pytz in /opt/conda/lib/python3.12/site-packages (from datetime->widetrax) (2024.1)
# Collecting cftime (from netCDF4->widetrax)
#   Downloading cftime-1.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from netCDF4->widetrax) (2024.8.30)
# Requirement already satisfied: pandas>=2.1 in /opt/conda/lib/python3.12/site-packages (from xarray->widetrax) (2.2.3)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.1->xarray->widetrax) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->widetrax) (1.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.12/site-packages (from zope.interface->datetime->widetrax) (74.1.2)
# Downloading widetrax-0.0.1-py3-none-any.whl (14 kB)
# Downloading Cartopy-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 26.2 MB/s eta 0:00:00a 0:00:01
# Downloading DateTime-5.5-py3-none-any.whl (52 kB)
# Downloading netCDF4-1.7.1.post2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 93.1 MB/s eta 0:00:00
# Downloading xarray-2024.9.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 50.1 MB/s eta 0:00:00
# Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
# Downloading cftime-1.6.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.6 MB/s eta 0:00:00
# Downloading zope.interface-7.0.3-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (267 kB)
# Installing collected packages: zope.interface, pyshp, cftime, netCDF4, datetime, xarray, cartopy, widetrax
# Successfully installed cartopy-0.23.0 cftime-1.6.4 datetime-5.5 netCDF4-1.7.1.post2 pyshp-2.3.1 widetrax-0.0.1 xarray-2024.9.0 zope.interface-7.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pyinterp
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - pyinterp
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-24.9.1               |  py312h7900ff3_0         1.1 MB  conda-forge
#     libboost-1.86.0            |       hb8260a3_2         2.9 MB  conda-forge
#     openblas-0.3.27            |pthreads_h9eca1d5_1         5.5 MB  conda-forge
#     pyinterp-2024.6.0          |openblas_py312h6043fca_102         4.3 MB  conda-forge
#     xarray-2024.9.0            |     pyhd8ed1ab_0         784 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        14.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   libboost           conda-forge/linux-64::libboost-1.86.0-hb8260a3_2
#   openblas           conda-forge/linux-64::openblas-0.3.27-pthreads_h9eca1d5_1
#   pyinterp           conda-forge/linux-64::pyinterp-2024.6.0-openblas_py312h6043fca_102
#   xarray             conda-forge/noarch::xarray-2024.9.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   conda                              24.7.1-py312h7900ff3_0 --> 24.9.1-py312h7900ff3_0
#
#
#
# Downloading and Extracting Packages:
# openblas-0.3.27      | 5.5 MB    |                                       |   0%
# pyinterp-2024.6.0    | 4.3 MB    |                                       |   0%
#
# libboost-1.86.0      | 2.9 MB    |                                       |   0%
#
#
# conda-24.9.1         | 1.1 MB    |                                       |   0%
#
#
#
# openblas-0.3.27      | 5.5 MB    | ##2                                   |   6%
# pyinterp-2024.6.0    | 4.3 MB    | ###3                                  |   9%
#
# libboost-1.86.0      | 2.9 MB    | ###########################1          |  74%
#
#
# conda-24.9.1         | 1.1 MB    | ####7                                 |  13%
#
#
#
# openblas-0.3.27      | 5.5 MB    | #############################8        |  81%
#
#
#
# xarray-2024.9.0      | 784 KB    | ##################################### | 100%
#
# libboost-1.86.0      | 2.9 MB    | ##################################### | 100%
#
#
# conda-24.9.1         | 1.1 MB    | ##################################### | 100%
#
#
# conda-24.9.1         | 1.1 MB    | ##################################### | 100%
# pyinterp-2024.6.0    | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Imports/Libraries 📦

# %%
import pyinterp
from widetrax import Spectram as sp
from widetrax import DataPreprocessing as dp
import matplotlib.pyplot as plt

# %% [markdown]
# ### Required variables 🧮

# %%
#Med region
area = [0, 35.5, 8, 43.5]
start_date = '20230701'  # the desired start date in YYYYMMDD format
end_date = '20230930'  
resolution = 0.1

# %% [markdown]
# ## 1. Research and extract data on the desired region and time period🌍

# %% [markdown]
# we extract the xarray datasets for the selected region of interest.

# %%
database_path = 'SWOT_data/'
matching_folders = dp.check_directory(database_path, start_date, end_date)
combined_datasets = dp.extract_xarrays_by_time(database_path, start_date, end_date, area)

# %%
combined_datasets[0]
# Out:
# <xarray.Dataset> Size: 1MB
# Dimensions:    (num_lines: 471, num_pixels: 69)
# Coordinates:
#     latitude   (num_lines, num_pixels) float64 260kB 43.79 43.78 ... 35.27 35.26
#     longitude  (num_lines, num_pixels) float64 260kB 2.667 2.643 ... 3.621 3.6
# Dimensions without coordinates: num_lines, num_pixels
# Data variables:
#     mdt        (num_lines, num_pixels) float64 260kB dask.array<chunksize=(471, 69), meta=np.ndarray>
#     ssha       (num_lines, num_pixels) float64 260kB dask.array<chunksize=(471, 69), meta=np.ndarray>
# Attributes: (12/42)
#     Conventions:                     CF-1.7
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Swath
#     comment:                         Sea Surface Height measured by Altimetry
#     geospatial_lat_units:            degrees_north
#     geospatial_lon_units:            degrees_east
#     ...                              ...
#     time_coverage_begin:             2023-08-01T15:05:24Z
#     time_coverage_end:               2023-08-01T15:56:50Z
#     geospatial_lat_min:              -78.271903
#     geospatial_lat_max:              78.272068
#     geospatial_lon_min:              0.000145
#     geospatial_lon_max:              359.999951

# %% [markdown]
# ## 2. Count the number of observations per bin 🔢

# %% [markdown]
# We check and plot the data density in the selected region

# %%
obs_count = dp.count_observations(combined_datasets, area, resolution)
#Plot
dp.plot_obs_count(obs_count, area, title='Number of observations')
# Out:
# /opt/conda/lib/python3.12/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_land.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)
# /opt/conda/lib/python3.12/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/10m_physical/ne_10m_coastline.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# ## 3. Handling and Interpolating Potential NaN Values 🛠️

# %%
has_converged, filled_datasets = dp.fill_nan(combined_datasets)

# %% [markdown]
# ## 4. Extract segments ✂️

# %%
# %%time
segments_dict = sp.retrieve_segments(filled_datasets,FileType="NetCDF")
# Out:
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:38: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   for col in range(dataset.dims['num_pixels']):
# CPU times: user 8.72 s, sys: 274 ms, total: 8.99 s
# Wall time: 9.18 s

# %% [markdown]
# ## 5. Calculate the Power Number Spectra (**PSD**) 📊

# %%
psd_dict, freqs_dict = sp.calculate_psd(segments_dict)
# Calculate PSD Mean
psd_mean, freqs_mean = sp.psd_mean_and_freq(psd_dict,freqs_dict)

# %% [markdown]
# ## 6. Plot 📉🖼️

# %%
fig, ax_ = plt.subplots(1, 1, figsize=(8, 8))
# Plot PSD
title = 'Mediterranean sea'
sp.plot_psd(ax_, freqs_mean, psd_mean, unit = "m2",psd_labels="PSD",title=title)
# Out:
# /opt/conda/lib/python3.12/site-packages/widetrax/Spectram.py:221: RuntimeWarning: divide by zero encountered in divide
#   ax2 = ax.secondary_xaxis("bottom", functions=(lambda x: 1 / x, lambda x: 1 / x))

# %% [markdown]
# ### **Conclusion** ✅📜
#
# - we successfully downloaded the SWOT data from Earthdata PODAAC.
# - we found that only SSH L2 data was available.
# - the `widetrax` package is designed to work with L3 data ==> As a result, many of the package's functions didn't perform as expected.
#
# From this issue, two important takeaways can be highlighted:
#
# 1. **Adaptation of `widetrax` for L2 data**: It would be beneficial if the `widetrax` package could be adapted to also support L2 data, allowing for more flexibility in different data processing scenarios.
#
# 2. **Availability of SWOT data on the EDITO platform**: Having SWOT data available on the EDITO platform in the future would facilitate data access and streamline various processing workflows.
