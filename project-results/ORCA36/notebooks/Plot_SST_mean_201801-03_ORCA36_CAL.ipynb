# %%
pip install cartopy cmocean
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotting_functions as pf
import xarray as xr
import cmocean
import numpy as np
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
min_lonGS = -140
min_latGS = 20
max_lonGS = -105
max_latGS = 40

# %%
data=xr.open_dataset('../../../../work/daily_mean_sst_CAL_201801-03.nc')

# %%
data
# Out:
# <xarray.Dataset> Size: 414MB
# Dimensions:             (y: 888, x: 1266, time_counter: 90)
# Coordinates:
#     nav_lat             (y, x) float32 4MB ...
#     nav_lon             (y, x) float32 4MB ...
# Dimensions without coordinates: y, x, time_counter
# Data variables:
#     daily_mean_sst_CAL  (time_counter, y, x) float32 405MB ...

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_CAL.mean(dim='time_counter'),data.nav_lon,data.nav_lat,'Mean sea surface temperature for 2018 January to March (ORCA36)', '°C', 12, 22, cmocean.cm.thermal,"../plots/ORCA36_MEAN-SST_CAL_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_CAL.std(dim='time_counter'),data.nav_lon,data.nav_lat,'Standart deviation of sea surface temperature for 2018 January to March (ORCA36)', '°C', 0, 2, cmocean.cm.amp,"../plots/ORCA36_STD-SST_CAL_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)
# Out:
# /opt/mamba/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
