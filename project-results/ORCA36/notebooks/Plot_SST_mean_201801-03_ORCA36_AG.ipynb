# %%
pip install cartopy cmocean
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotting_functions as pf
import xarray as xr
import cmocean
import numpy as np
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
min_lonGS = 15
min_latGS = -50
max_lonGS = 50
max_latGS = -30

# %%
data=xr.open_dataset('../../../../work/daily_mean_sst_AG_201807-09.nc')

# %%
data.daily_mean_sst_AG
# Out:
# <xarray.DataArray 'daily_mean_sst_AG' (time_counter: 91, y: 951, x: 1261)> Size: 437MB
# [109128201 values with dtype=float32]
# Coordinates:
#     nav_lat  (y, x) float32 5MB ...
#     nav_lon  (y, x) float32 5MB ...
# Dimensions without coordinates: time_counter, y, x

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_AG.mean(dim='time_counter'),data.nav_lon,data.nav_lat,'Mean sea surface temperature for 2018 January to March (ORCA36)', '°C', 4, 20, cmocean.cm.thermal,"../plots/ORCA36_MEAN-SST_AG_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_AG.std(dim='time_counter'),data.nav_lon,data.nav_lat,'Standart deviation of sea surface temperature for 2018 January to March (ORCA36)', '°C', 0, 2, cmocean.cm.amp,"../plots/ORCA36_STD-SST_AG_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)
# Out:
# /opt/mamba/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
