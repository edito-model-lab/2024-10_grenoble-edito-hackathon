# %%
pip install cartopy cmocean
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 80.3 MB/s eta 0:00:00:00:01:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.9/421.9 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 3.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import plotting_functions as pf
import xarray as xr
import cmocean
import numpy as np
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/mamba/share/proj failed

# %%
min_lonGS = 140
min_latGS = 25
max_lonGS = 170
max_latGS = 45

# %%
data=xr.open_dataset('../../../../work/daily_mean_sst_KU_201801-03.nc')

# %%
data.daily_mean_sst_KU
# Out:
# <xarray.DataArray 'daily_mean_sst_KU' (time_counter: 90, y: 922, x: 1082)> Size: 359MB
# [89784360 values with dtype=float32]
# Coordinates:
#     nav_lat  (y, x) float32 4MB ...
#     nav_lon  (y, x) float32 4MB ...
# Dimensions without coordinates: time_counter, y, x

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_KU.mean(dim='time_counter'),data.nav_lon,data.nav_lat,'Mean sea surface temperature for 2018 January to March (ORCA36)', '°C', 5, 22, cmocean.cm.thermal,"../plots/ORCA36_MEAN-SST_KU_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)

# %%
pf.map_mean_GS_ORCA36(data.daily_mean_sst_KU.std(dim='time_counter'),data.nav_lon,data.nav_lat,'Standart deviation of sea surface temperature for 2018 January to March (ORCA36)', '°C', 0, 2, cmocean.cm.amp,"../plots/ORCA36_STD-SST_KU_201801-03.png",min_lonGS, max_lonGS, min_latGS, max_latGS)
# Out:
# /opt/mamba/lib/python3.11/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
